# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

import sklearn.metrics
from sklearn import metrics
from sklearn.metrics import f1_score

# %%
datasets = pd.read_csv('/content/drive/MyDrive/Mamun_vai_analysis/ALL_FFT.csv')

# %%
# Importing the datasets
X = datasets.iloc[:, 0:31].values
Y = datasets.iloc[:, 32].values

# %%
# Splitting the dataset into the Training set and Test set
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
# Feature Scaling
sc_X = StandardScaler()
X_Train = sc_X.fit_transform(X_Train)
X_Test = sc_X.transform(X_Test)
 
# Fitting the classifier into the Training set
#kernel = precomputed, rbf,linear,polynomial, poly
 
classifier = SVC(kernel = 'rbf', gamma='scale',random_state = 0, max_iter=-1,  tol=0.0001,degree=3, verbose=False, class_weight=None, C=500.0)
classifier.fit(X_Train, Y_Train)
 
# Predicting the test set results
Y_Pred = classifier.predict(X_Test)

# %%
# Making the Confusion Matrix 
cm = confusion_matrix(Y_Test, Y_Pred)
cm
# Out:
# array([[897,   0],
#        [  1, 906]])

# %%
print("Accuracy:",metrics.accuracy_score(Y_Test, Y_Pred))
print("Precision:",metrics.precision_score(Y_Test, Y_Pred))
print("Recall:",metrics.recall_score(Y_Test, Y_Test))
print("F1_Score:",metrics.f1_score(Y_Test, Y_Test))
print("Cohen_Kappa_Score:",sklearn.metrics.cohen_kappa_score(Y_Test, Y_Pred, labels=None, weights=None, sample_weight=None))
# Out:
# Accuracy: 0.9994456762749445
# Precision: 0.9988864142538976
# Recall: 1.0
# F1_Score: 1.0
# Cohen_Kappa_Score: 0.998891325296466
